# %%
from packaging import version
import sklearn
import tensorflow as tf

print(f"tensorflow version {tf.__version__}")
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
# Out:
# tensorflow version 2.19.0

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris(as_frame=True)

# %%
iris.data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris.target
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
import matplotlib.pyplot as plt

_, ax = plt.subplots()
scatter = ax.scatter(
        iris.data.iloc[:, 0],
        iris.data.iloc[:, 1],
        c=iris.target
        )
ax.set(
        xlabel=iris.feature_names[0],
        ylabel=iris.feature_names[1]
        )
ax.legend(
        scatter.legend_elements()[0],
        iris.target_names,
        loc="lower right",
        title="Classes"
        )
plt.show()

# %%
X = iris.data[["petal length (cm)", "petal width (cm)"]].values
X
# Out:
# array([[1.4, 0.2],
#        [1.4, 0.2],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.7, 0.4],
#        [1.4, 0.3],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.5, 0.1],
#        [1.5, 0.2],
#        [1.6, 0.2],
#        [1.4, 0.1],
#        [1.1, 0.1],
#        [1.2, 0.2],
#        [1.5, 0.4],
#        [1.3, 0.4],
#        [1.4, 0.3],
#        [1.7, 0.3],
#        [1.5, 0.3],
#        [1.7, 0.2],
#        [1.5, 0.4],
#        [1. , 0.2],
#        [1.7, 0.5],
#        [1.9, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.4],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.2],
#        [1.5, 0.4],
#        [1.5, 0.1],
#        [1.4, 0.2],
#        [1.5, 0.2],
#        [1.2, 0.2],
#        [1.3, 0.2],
#        [1.4, 0.1],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.3, 0.3],
#        [1.3, 0.3],
#        [1.3, 0.2],
#        [1.6, 0.6],
#        [1.9, 0.4],
#        [1.4, 0.3],
#        [1.6, 0.2],
#        [1.4, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [4.7, 1.4],
#        [4.5, 1.5],
#        [4.9, 1.5],
#        [4. , 1.3],
#        [4.6, 1.5],
#        [4.5, 1.3],
#        [4.7, 1.6],
#        [3.3, 1. ],
#        [4.6, 1.3],
#        [3.9, 1.4],
#        [3.5, 1. ],
#        [4.2, 1.5],
#        [4. , 1. ],
#        [4.7, 1.4],
#        [3.6, 1.3],
#        [4.4, 1.4],
#        [4.5, 1.5],
#        [4.1, 1. ],
#        [4.5, 1.5],
#        [3.9, 1.1],
#        [4.8, 1.8],
#        [4. , 1.3],
#        [4.9, 1.5],
#        [4.7, 1.2],
#        [4.3, 1.3],
#        [4.4, 1.4],
#        [4.8, 1.4],
#        [5. , 1.7],
#        [4.5, 1.5],
#        [3.5, 1. ],
#        [3.8, 1.1],
#        [3.7, 1. ],
#        [3.9, 1.2],
#        [5.1, 1.6],
#        [4.5, 1.5],
#        [4.5, 1.6],
#        [4.7, 1.5],
#        [4.4, 1.3],
#        [4.1, 1.3],
#        [4. , 1.3],
#        [4.4, 1.2],
#        [4.6, 1.4],
#        [4. , 1.2],
#        [3.3, 1. ],
#        [4.2, 1.3],
#        [4.2, 1.2],
#        [4.2, 1.3],
#        [4.3, 1.3],
#        [3. , 1.1],
#        [4.1, 1.3],
#        [6. , 2.5],
#        [5.1, 1.9],
#        [5.9, 2.1],
#        [5.6, 1.8],
#        [5.8, 2.2],
#        [6.6, 2.1],
#        [4.5, 1.7],
#        [6.3, 1.8],
#        [5.8, 1.8],
#        [6.1, 2.5],
#        [5.1, 2. ],
#        [5.3, 1.9],
#        [5.5, 2.1],
#        [5. , 2. ],
#        [5.1, 2.4],
#        [5.3, 2.3],
#        [5.5, 1.8],
#        [6.7, 2.2],
#        [6.9, 2.3],
#        [5. , 1.5],
#        [5.7, 2.3],
#        [4.9, 2. ],
#        [6.7, 2. ],
#        [4.9, 1.8],
#        [5.7, 2.1],
#        [6. , 1.8],
#        [4.8, 1.8],
#        [4.9, 1.8],
#        [5.6, 2.1],
#        [5.8, 1.6],
#        [6.1, 1.9],
#        [6.4, 2. ],
#        [5.6, 2.2],
#        [5.1, 1.5],
#        [5.6, 1.4],
#        [6.1, 2.3],
#        [5.6, 2.4],
#        [5.5, 1.8],
#        [4.8, 1.8],
#        [5.4, 2.1],
#        [5.6, 2.4],
#        [5.1, 2.3],
#        [5.1, 1.9],
#        [5.9, 2.3],
#        [5.7, 2.5],
#        [5.2, 2.3],
#        [5. , 1.9],
#        [5.2, 2. ],
#        [5.4, 2.3],
#        [5.1, 1.8]])

# %%
y = (iris.target == 0)  # Iris setosa
y
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: target, Length: 150, dtype: bool

# %%
per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)
accuracy = per_clf.score(X, y)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 1.0

# %%
per_clf.predict([[2, 0.5], [3, 1]])
# Out:
# array([ True, False])

# %%
X_new = [[2, 0.5], [3, 1]]
y_pred = per_clf.predict(X_new)  # predicts True and False for these 2 flowers
print(y_pred)
# Out:
# [ True False]

# %%
from sklearn.model_selection import train_test_split

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(
        iris.data, iris.target, test_size=0.1, random_state=42
        )

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score

clf = Perceptron(random_state=42)
clf.fit(X_train, y_train)

clf.predict([[2, 0.5, 3, 1]])
# Out:
# array([2])

# %%
def evaluate(model, X_test, y_test):
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average="macro")
    recall = recall_score(y_test, y_pred, average="macro")
    print(f"Accuracy: {accuracy:0.2f}")
    print(f"Precision: {precision:0.2f}")
    print(f"Recall: {recall:0.2f}")
    return accuracy, precision, recall


evaluate(clf, X_test, y_test)
# Out:
# Accuracy: 0.80
# Precision: 0.56
# Recall: 0.67
# /Users/thomasbayer/Projects/PycharmProjects/lecture/dl_summer/.venv312/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# (0.8, 0.5555555555555555, 0.6666666666666666)

# %%
from sklearn.linear_model import LogisticRegression

lr_clf = LogisticRegression(random_state=42, max_iter=100, verbose=2)
lr_clf.fit(X_train, y_train)
evaluate(lr_clf, X_test, y_test)
# Out:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# (1.0, 1.0, 1.0)

# %%
print(clf.predict([[2, 0.5, 3, 1]])[0])
lr_clf.predict([[2, 0.5, 3, 1]])
# Out:
# 2
# array([1])

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import make_pipeline

mlp_clf = MLPClassifier(
        hidden_layer_sizes=[5, 5],
        max_iter=10_000,
        random_state=42
        )
pipeline = make_pipeline(mlp_clf)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('mlpclassifier',
#                  MLPClassifier(hidden_layer_sizes=[5, 5], max_iter=10000,
#                                random_state=42))])

# %%
mlp_clf.predict([[2, 0.5, 3, 1]])
# Out:
# array([2])

# %%
evaluate(pipeline, X_test, y_test)
# Out:
# Accuracy: 0.93
# Precision: 0.92
# Recall: 0.94
# (0.9333333333333333, 0.9166666666666666, 0.9444444444444445)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (135, 4)
# (135,)

# %%
print(X_train.shape)
print(y_test.shape)
# Out:
# (135, 4)
# (15,)
